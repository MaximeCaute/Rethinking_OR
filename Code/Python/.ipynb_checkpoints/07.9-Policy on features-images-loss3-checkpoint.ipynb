# %% [markdown]
# ##  07.8 - Learning Policy on Image + Attributes - loss 3
#
# Fully connected network with:
# - Input:
#     - **184** size vector with:
#         * client information: [current latitude, current longitud, destination latitude, destination longitude]
#         * vehicles information: [load, queue, current latitude, current longitud, next latitude, next longitude]
#     - Image with 31 channel:
#         * Channel 0 --> client representation. its current location is marked as 1; its destination as -1
#         * Channels > 0 --> vehicle current location (1)
#
# - Output: One hot encoding vector with 30 entries representing the available vehicles
#
#
# The attribute input is merged later with a partial output of the network
#
# loss 1: vehicle assignment
# loss 3: cosine similarity between the predicted vehicle and the target one

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch
import numpy as np
import pandas as pd
import random
import tqdm
import time

import matplotlib.pyplot as plt

from torch.utils.data import Dataset
from torch import optim

# %%
class ImagesP3(nn.Module):
    def __init__(self, inp1, num_v, im_size):
        super().__init__()

        ins = 10
        cs = 5
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(inp1, ins, kernel_size=cs),
            nn.BatchNorm2d(ins),
            nn.ReLU(),
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(ins, 5, kernel_size=cs),
            nn.BatchNorm2d(5),
            nn.ReLU(),
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(5, 2, kernel_size=cs),
            nn.BatchNorm2d(2),
            nn.ReLU(),
        )
        self.fc1 = nn.Sequential(
            nn.Linear(2*(im_size - 3*(cs-1))*(im_size - 3*(cs-1)), 264),
            nn.ReLU(),
        
        )
        
        self.fc2 = nn.Sequential(
            nn.Linear(264, num_v),
        )
        
        self.f_aux = nn.Sequential(
            nn.Linear(num_v, 2)
        )
        
        self.fc3 = nn.Sequential(
            nn.Linear(7*num_v, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(),
        )
        
        self.fc4 = nn.Sequential(
            nn.Linear(100, num_v),
            nn.BatchNorm1d(num_v),
            nn.ReLU(),
        )
        

    def forward(self, x, v_x):
        num_v = v_x.shape[1] 
        cs = 5
        
        x0 = x
        x1 = self.conv1(x0)
        x2 = self.conv2(x1)
        x3 = self.conv3(x2)
        x4 = x3.view(-1, 2*(x.shape[-1] - 3*(cs-1))*(x.shape[-1] - 3*(cs-1)))
        x5 = self.fc1(x4)
        x6 = self.fc2(x5)
        
        x_aux = self.f_aux(x6)
        # add vehicles information
        x7 = torch.cat([v_x.transpose(2,1) ,x6.view(-1, 1,v_x.shape[1] )], dim=1).view(v_x.shape[0], -1)
        
        x8 = self.fc3(x7)
        x9 = self.fc4(x8)
        
        return x_aux, x9

# %%
def epoch_train(model, train_table, test_tables, optimizer, criterion1, criterion2, e, im_size=30, weighted=0.5):
    
    cos = nn.CosineSimilarity(dim=1, eps=1e-6)
    sum_loss = 0
    acc = []
    idx_failures = []
    dist = 1/(im_size-1)

    # train data
    for k, TABLE in enumerate(train_tables):
        
        data = np.load('./minmax_data/data_vector_{}.npy'.format(TABLE), allow_pickle=True).tolist()
        data_y = np.load('./minmax_data/data_vector_y_{}.npy'.format(TABLE), allow_pickle=True).tolist()

        idx = list(data.keys())
        nv = len(data[idx[0]]) - 1
        
        

        for b in range(0, len(idx), mini_batch_size):
            # idx of clients to analyse
            t_idx = idx[b:b+mini_batch_size]
            
            x = np.zeros((len(t_idx), nv+1, im_size, im_size))
            loc_y = np.zeros((len(t_idx), 2))
            x_aux = []
            
            for k, cl in enumerate(t_idx):
                loc = int(data_y[cl])
                loc_y[k] = [data[cl][loc+1][2], data[cl][loc+1][3]]
                
                x_aux.append(torch.tensor(np.asarray(data[cl][1:])).type(torch.FloatTensor))
                x[k][0][int(data[cl][0][0]//dist)][int(data[cl][0][1]//dist)] = 1
                x[k][0][int(data[cl][0][2]//dist)][int(data[cl][0][3]//dist)] = -1

                for i in range(1,31):
                    x[k][i][int(data[cl][i][2]//dist)][int(data[cl][i][3]//dist)] = 1
            
            y = np.hstack([data_y[i] for i in t_idx])
           
            train_x = torch.tensor(x).type(torch.FloatTensor)
            train_x_aux = torch.stack(x_aux).type(torch.FloatTensor)
            train_y = torch.tensor(y).type(torch.LongTensor)
            train_y_aux = torch.tensor(loc_y).type(torch.FloatTensor)
            
            # set gradient to zero
            optimizer.zero_grad()
            
            # compute output
            output1, output2 = model(train_x, train_x_aux)
            _, idx_max = output2.max(1)
            
            loss2 = torch.mean(abs(cos(train_x_aux[list(range(len(t_idx))), list(train_y)], \
                                      train_x_aux[list(range(len(t_idx))), list(idx_max)])))
            
            
            batch_loss = weighted*criterion1(output1, train_y_aux) + (1- weighted)*(1-loss2)
            
            batch_loss.backward()
            optimizer.step()

            sum_loss = sum_loss + batch_loss.item()
            _, a = torch.max(output2,1)
            acc.append(float((train_y == a).sum())/len(train_y))
            
    
    
    test_loss = 0
    test_acc = []
    
    for k,TABLE in enumerate(test_tables):
        data = np.load('./minmax_data/data_vector_{}.npy'.format(TABLE), allow_pickle=True).tolist()
        data_y = np.load('./minmax_data/data_vector_y_{}.npy'.format(TABLE), allow_pickle=True).tolist()
        
        idx = list(data.keys())
        #random.shuffle(idx)
        
        for b in range(0, len(idx), mini_batch_size):

            t_idx = idx[b:b+mini_batch_size]
            
            x = np.zeros((len(t_idx), nv+1, im_size, im_size))
            loc_y = np.zeros((len(t_idx), 2))
            x_aux = []
            
            for k, cl in enumerate(t_idx):
                loc = int(data_y[cl])
                loc_y[k] = [data[cl][loc+1][2], data[cl][loc+1][3]]
                
                x_aux.append(torch.tensor(np.asarray(data[cl][1:])).type(torch.FloatTensor))
                x[k][0][int(data[cl][0][0]//dist)][int(data[cl][0][1]//dist)] = 1
                x[k][0][int(data[cl][0][2]//dist)][int(data[cl][0][3]//dist)] = -1

                for i in range(1,31):
                    x[k][i][int(data[cl][i][2]//dist)][int(data[cl][i][3]//dist)] = 1
            
            y = np.hstack([data_y[i] for i in t_idx])
            
            
            test_x = torch.tensor(x).type(torch.FloatTensor)
            test_x_aux = torch.stack(x_aux).type(torch.FloatTensor)
            test_y = torch.tensor(y).type(torch.LongTensor)
            test_y_aux = torch.tensor(loc_y).type(torch.FloatTensor)
            
            output1, output2 = model(test_x, test_x_aux)
            _, idx_max = output2.max(1)
            
            loss2 = torch.mean(abs(cos(test_x_aux[list(range(len(t_idx))), list(test_y)], \
                                      test_x_aux[list(range(len(t_idx))), list(idx_max)])))
            
            
            batch_loss = weighted*criterion1(output1, test_y_aux) + (1- weighted)*(1-loss2)

            test_loss += batch_loss.item()
            _, a = torch.max(output2,1)
            
            test_acc.append(float((test_y == a).sum())/len(test_y))
            idx_failures += [t_idx[i] for i in np.where(test_y != a)[0]]
            
            
    #print('\rEpoch {}. Train Loss: {:.3f} Accuracy: {:.3f} Test Loss: {:.3f} Accuracy: {:.3f}'.format(e+1, sum_loss, np.mean(acc), test_loss,np.mean(test_acc)), end="")
    print('\rEpoch {}. Train Loss: {:.3f} Test Loss: {:.3f}'.format(e+1, sum_loss, test_loss), end="")
    return sum_loss, np.sum(acc)/len(acc), test_loss, np.sum(test_acc)/len(test_acc), idx_failures, output2

# %% [markdown]
# ### General configurations

# %%
random.seed(4915)
global MAX_V, mini_batch_size, n_epochs, lr, inp_size
MAX_V = 30
mini_batch_size = 50
n_epochs=50

tables = list(range(1,90))
random.shuffle(tables)

lr = 0.0001
inp_size = 4 + MAX_V*6

train_tables, test_tables, validation_tables = \
            tables[:int(len(tables)*0.6)], tables[int(len(tables)*0.6):int(len(tables)*0.9)], \
            tables[int(len(tables)*0.9):]

# %%
model = ImagesP3(80, MAX_V, 100)

# %%
print('Total num of parameters: {}'.format(sum(p.numel() for p in model.parameters())))
print('Num of trainable parameters: {}'.format(sum(p.numel() for p in model.parameters() if p.requires_grad)))
# Out:
# Total num of parameters: 4143049
# Num of trainable parameters: 4143049

# %% [markdown]
# ### Functions

# %%
def evaluating_model(im_size, weighted=0.5):
    model = ImagesP3(31, MAX_V, im_size)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion2 = nn.CrossEntropyLoss() 
    criterion1 = nn.MSELoss() 
    
    loss, acc, test_loss, test_acc, idx_f, times = [], [], [], [], [], []

    for epoch in range(n_epochs):
        current_t = time.time()
        train_l, accuracy, test_l, test_a, idx_failures, o2 = \
        epoch_train(model, train_tables, test_tables, optimizer, criterion1, criterion2, epoch, im_size, weighted)
        
        times.append(time.time() - current_t)
        loss.append(train_l)
        test_loss.append(test_l)
        acc.append(accuracy)
        test_acc.append(test_a)
        idx_f.append(idx_failures)

    print('\nAverage time per epoch {:.3f}s +- {:.3f}'.format(np.mean(times), 2*np.std(times)))

    max_acc = np.max(test_acc)
    iter_max = np.where(test_acc ==  max_acc)

    print('Max accuracy of {:.3f} achieved at epoch {}'.format(max_acc, iter_max[0][0]))
    
    return loss, acc, test_loss, test_acc, idx_f, times, o2


def visualize_results(loss, test_loss, acc, test_acc, idx_f):
    f, ax = plt.subplots(2, 1, figsize=(20,8))
    ax[0].plot(loss)
    ax[0].plot(test_loss)
    ax[1].plot(acc)
    ax[1].plot(test_acc)
    plt.show()
    
    max_acc = np.max(test_acc)
    iter_max = np.where(test_acc ==  max_acc) 
    iter_max = iter_max[0][0]

    fig, ax = plt.subplots(1,5, figsize=(20,4))
    k = 0
    idx = idx_f[:iter_max+1]
    for j, i in enumerate(idx[::-1]):
        if len(i) > 0:
            ax[k].hist(i, bins=50)
            ax[k].set_xlabel('Client')
            ax[k].set_ylabel('Num errors')
            ax[k].set_title('Iteration {}\nwith acc:{:.3f}'.format(-j + iter_max, test_acc[-j + iter_max]))
            k += 1
        if k == 5:
            plt.show()
            break

# %% [markdown]
# ### Model 1. simple; image size = 15

# %%
loss, acc, test_loss, test_acc, idx_f, times, o2 = evaluating_model(20, weighted=0.5)
visualize_results(loss, test_loss, acc, test_acc, idx_f)
# Out:
# Epoch 50. Train Loss: 22.495 Test Loss: 13.973
# Average time per epoch 6.778s +- 0.886
# Max accuracy of 0.050 achieved at epoch 24

# %% [markdown]
# ### Model 2. Multiple loss; image size = 15

# %%
loss, acc, test_loss, test_acc, idx_f, times, o2 = evaluating_model(20)
visualize_results(loss, test_loss, acc, test_acc, idx_f)
# Out:
# Epoch 9. Train Loss: -1518.040 Accuracy: 0.039 Test Loss: -760.325 Accuracy: 0.038
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-f23c9fa86bc8> in <module>
# ----> 1 loss, acc, test_loss, test_acc, idx_f, times, o2 = evaluating_model(20)
#       2 visualize_results(loss, test_loss, acc, test_acc, idx_f)
#
# <ipython-input-9-996c9af18ea9> in evaluating_model(im_size, weighted)
#      10         current_t = time.time()
#      11         train_l, accuracy, test_l, test_a, idx_failures, o2 = \
# ---> 12         epoch_train(model, train_tables, test_tables, optimizer, criterion1, criterion2, epoch, im_size, weighted)
#      13
#      14         times.append(time.time() - current_t)
#
# <ipython-input-48-180cd843e2ca> in epoch_train(model, train_table, test_tables, optimizer, criterion1, criterion2, e, im_size, weighted)
#      48
#      49             # compute output
# ---> 50             output1, output2 = model(train_x, train_x_aux)
#      51             _, idx_max = output2.max(1)
#      52
#
# ~/miniconda3/envs/vehicles/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-4-6a8c4189b61d> in forward(self, x, v_x)
#      53
#      54         x0 = x
# ---> 55         x1 = self.conv1(x0)
#      56         x2 = self.conv2(x1)
#      57         x3 = self.conv3(x2)
#
# ~/miniconda3/envs/vehicles/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/vehicles/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/miniconda3/envs/vehicles/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/vehicles/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# ~/miniconda3/envs/vehicles/lib/python3.7/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# KeyboardInterrupt:

# %%
loss, acc, test_loss, test_acc, idx_f, times, o2 = evaluating_model(20, weighted=0.99)
visualize_results(loss, test_loss, acc, test_acc, idx_f)
# Out:
# Epoch 50. Train Loss: 4.926 Accuracy: 0.518 Test Loss: 172.330 Accuracy: 0.179
# Average time per epoch 5.644s +- 0.468
# Max accuracy of 0.196 achieved at epoch 24

# %%
loss, acc, test_loss, test_acc, idx_f, times, o2 = evaluating_model(20, weighted=0.1)
visualize_results(loss, test_loss, acc, test_acc, idx_f)
# Out:
# Epoch 50. Train Loss: 140.493 Accuracy: 0.782 Test Loss: 177.907 Accuracy: 0.156
# Average time per epoch 5.735s +- 0.288
# Max accuracy of 0.170 achieved at epoch 15

# %%
loss, acc, test_loss, test_acc, idx_f, times, o2 = evaluating_model(20, weighted=0.01)
visualize_results(loss, test_loss, acc, test_acc, idx_f)
# Out:
# Epoch 50. Train Loss: 157.644 Accuracy: 0.771 Test Loss: 177.552 Accuracy: 0.160
# Average time per epoch 5.497s +- 0.288
# Max accuracy of 0.172 achieved at epoch 14

# %%
total_acc, total_loss = [], []
for w in [0.1, 0.3, 0.5, 0.7, 0.9]:
    main_acc, main_loss = [], []
    for trial in range(5):
        loss, acc, test_loss, test_acc, idx_f, times, o2 = evaluating_model(20, weighted=w)
        main_loss.append(min(test_loss))
        main_acc.append(max(test_acc))
    total_acc.append(main_acc)
    total_loss.append(main_loss)
    print('Average accuracy {:.3f} +- {:.3f}. Av loss {:.3f}'.format(np.mean(main_acc), np.std(main_acc), np.mean(main_loss)))
# Out:
# Epoch 50. Train Loss: 141.576 Accuracy: 0.786 Test Loss: 175.390 Accuracy: 0.163
# Average time per epoch 5.700s +- 0.320
# Max accuracy of 0.173 achieved at epoch 43
# Epoch 50. Train Loss: 140.936 Accuracy: 0.791 Test Loss: 175.978 Accuracy: 0.160
# Average time per epoch 5.659s +- 0.184
# Max accuracy of 0.174 achieved at epoch 34
# Epoch 50. Train Loss: 146.746 Accuracy: 0.765 Test Loss: 176.652 Accuracy: 0.153
# Average time per epoch 5.673s +- 0.203
# Max accuracy of 0.180 achieved at epoch 20
# Epoch 50. Train Loss: 139.320 Accuracy: 0.787 Test Loss: 177.529 Accuracy: 0.160
# Average time per epoch 5.682s +- 0.112
# Max accuracy of 0.175 achieved at epoch 11
# Epoch 50. Train Loss: 140.280 Accuracy: 0.783 Test Loss: 176.742 Accuracy: 0.154
# Average time per epoch 5.666s +- 0.227
# Max accuracy of 0.171 achieved at epoch 15
# Average accuracy 0.174 +- 0.003. Av loss 173.870
# Epoch 50. Train Loss: 114.452 Accuracy: 0.765 Test Loss: 174.576 Accuracy: 0.162
# Average time per epoch 5.773s +- 0.204
# Max accuracy of 0.180 achieved at epoch 16
# Epoch 50. Train Loss: 111.875 Accuracy: 0.786 Test Loss: 175.325 Accuracy: 0.168
# Average time per epoch 5.625s +- 0.155
# Max accuracy of 0.174 achieved at epoch 10
# Epoch 50. Train Loss: 112.583 Accuracy: 0.767 Test Loss: 175.943 Accuracy: 0.155
# Average time per epoch 5.578s +- 0.111
# Max accuracy of 0.178 achieved at epoch 15
# Epoch 50. Train Loss: 111.407 Accuracy: 0.784 Test Loss: 177.669 Accuracy: 0.155
# Average time per epoch 5.582s +- 0.109
# Max accuracy of 0.180 achieved at epoch 17
# Epoch 50. Train Loss: 112.760 Accuracy: 0.773 Test Loss: 176.087 Accuracy: 0.161
# Average time per epoch 5.767s +- 0.339
# Max accuracy of 0.183 achieved at epoch 20
# Average accuracy 0.179 +- 0.003. Av loss 172.391
# Epoch 50. Train Loss: 81.983 Accuracy: 0.772 Test Loss: 177.642 Accuracy: 0.1570
# Average time per epoch 5.613s +- 0.185
# Max accuracy of 0.171 achieved at epoch 15
# Epoch 50. Train Loss: 81.501 Accuracy: 0.786 Test Loss: 175.893 Accuracy: 0.1635
# Average time per epoch 5.594s +- 0.109
# Max accuracy of 0.185 achieved at epoch 13
# Epoch 50. Train Loss: 83.293 Accuracy: 0.762 Test Loss: 173.107 Accuracy: 0.1816
# Average time per epoch 5.554s +- 0.097
# Max accuracy of 0.183 achieved at epoch 26
# Epoch 50. Train Loss: 82.843 Accuracy: 0.772 Test Loss: 175.957 Accuracy: 0.1521
# Average time per epoch 5.549s +- 0.107
# Max accuracy of 0.175 achieved at epoch 17
# Epoch 50. Train Loss: 81.013 Accuracy: 0.783 Test Loss: 177.479 Accuracy: 0.1679
# Average time per epoch 5.579s +- 0.170
# Max accuracy of 0.178 achieved at epoch 14
# Average accuracy 0.178 +- 0.005. Av loss 172.570
# Epoch 50. Train Loss: 52.872 Accuracy: 0.759 Test Loss: 174.582 Accuracy: 0.168
# Average time per epoch 5.724s +- 0.177
# Max accuracy of 0.188 achieved at epoch 33
# Epoch 50. Train Loss: 52.541 Accuracy: 0.767 Test Loss: 175.558 Accuracy: 0.165
# Average time per epoch 5.738s +- 0.106
# Max accuracy of 0.179 achieved at epoch 16
# Epoch 50. Train Loss: 53.929 Accuracy: 0.747 Test Loss: 176.542 Accuracy: 0.158
# Average time per epoch 5.714s +- 0.105
# Max accuracy of 0.172 achieved at epoch 18
# Epoch 50. Train Loss: 50.389 Accuracy: 0.786 Test Loss: 175.987 Accuracy: 0.162
# Average time per epoch 5.723s +- 0.115
# Max accuracy of 0.182 achieved at epoch 21
# Epoch 50. Train Loss: 52.767 Accuracy: 0.761 Test Loss: 175.115 Accuracy: 0.162
# Average time per epoch 5.809s +- 0.230
# Max accuracy of 0.188 achieved at epoch 15
# Average accuracy 0.182 +- 0.006. Av loss 172.285
# Epoch 50. Train Loss: 21.115 Accuracy: 0.700 Test Loss: 174.474 Accuracy: 0.174
# Average time per epoch 5.745s +- 0.199
# Max accuracy of 0.192 achieved at epoch 17
# Epoch 50. Train Loss: 20.789 Accuracy: 0.708 Test Loss: 174.537 Accuracy: 0.165
# Average time per epoch 5.788s +- 0.176
# Max accuracy of 0.183 achieved at epoch 15
# Epoch 50. Train Loss: 20.855 Accuracy: 0.704 Test Loss: 175.615 Accuracy: 0.166
# Average time per epoch 5.794s +- 0.186
# Max accuracy of 0.193 achieved at epoch 24
# Epoch 50. Train Loss: 21.460 Accuracy: 0.692 Test Loss: 174.747 Accuracy: 0.176
# Average time per epoch 5.829s +- 0.182
# Max accuracy of 0.199 achieved at epoch 17
# Epoch 50. Train Loss: 20.888 Accuracy: 0.702 Test Loss: 174.811 Accuracy: 0.181
# Average time per epoch 5.656s +- 0.225
# Max accuracy of 0.194 achieved at epoch 18
# Average accuracy 0.192 +- 0.005. Av loss 170.581

# %%
total_acc, total_loss = [], []
for w in [0.999]:
    main_acc, main_loss = [], []
    for trial in range(5):
        loss, acc, test_loss, test_acc, idx_f, times, o2 = evaluating_model(20, weighted=w)
        main_loss.append(min(test_loss))
        main_acc.append(max(test_acc))
    total_acc.append(main_acc)
    total_loss.append(main_loss)
    print('Average accuracy {:.3f} +- {:.3f}. Av loss {:.3f}'.format(np.mean(main_acc), np.std(main_acc), np.mean(main_loss)))
# Out:
# Epoch 50. Train Loss: 2.651 Accuracy: 0.521 Test Loss: 170.451 Accuracy: 0.190
# Average time per epoch 5.752s +- 0.281
# Max accuracy of 0.197 achieved at epoch 25
# Epoch 50. Train Loss: 2.645 Accuracy: 0.517 Test Loss: 169.935 Accuracy: 0.194
# Average time per epoch 5.757s +- 0.279
# Max accuracy of 0.199 achieved at epoch 35
# Epoch 50. Train Loss: 2.503 Accuracy: 0.515 Test Loss: 169.390 Accuracy: 0.196
# Average time per epoch 5.926s +- 0.333
# Max accuracy of 0.205 achieved at epoch 28
# Epoch 50. Train Loss: 2.666 Accuracy: 0.516 Test Loss: 168.072 Accuracy: 0.202
# Average time per epoch 5.935s +- 0.260
# Max accuracy of 0.211 achieved at epoch 39
# Epoch 50. Train Loss: 2.767 Accuracy: 0.514 Test Loss: 169.864 Accuracy: 0.196
# Average time per epoch 5.777s +- 0.167
# Max accuracy of 0.204 achieved at epoch 32
# Average accuracy 0.203 +- 0.005. Av loss 168.592

# %%
total_acc, total_loss = [], []

main_acc, main_loss = [], []
for trial in range(5):
    loss, acc, test_loss, test_acc, idx_f, times, o2 = evaluating_model(20, simple=True)
    main_loss.append(min(test_loss))
    main_acc.append(max(test_acc))
total_acc.append(main_acc)
total_loss.append(main_loss)
print('Average accuracy {:.3f} +- {:.3f}. Av loss {:.3f}'.format(np.mean(main_acc), np.std(main_acc), np.mean(main_loss)))
# Out:
# Epoch 50. Train Loss: 156.288 Accuracy: 0.788 Test Loss: 173.001 Accuracy: 0.159
# Average time per epoch 5.568s +- 0.321
# Max accuracy of 0.181 achieved at epoch 20
# Epoch 50. Train Loss: 157.674 Accuracy: 0.783 Test Loss: 172.861 Accuracy: 0.158
# Average time per epoch 5.856s +- 0.349
# Max accuracy of 0.181 achieved at epoch 21
# Epoch 50. Train Loss: 155.605 Accuracy: 0.790 Test Loss: 172.125 Accuracy: 0.165
# Average time per epoch 5.876s +- 0.243
# Max accuracy of 0.170 achieved at epoch 34
# Epoch 50. Train Loss: 156.660 Accuracy: 0.778 Test Loss: 173.051 Accuracy: 0.159
# Average time per epoch 5.880s +- 0.281
# Max accuracy of 0.176 achieved at epoch 22
# Epoch 50. Train Loss: 157.384 Accuracy: 0.775 Test Loss: 173.069 Accuracy: 0.158
# Average time per epoch 6.358s +- 1.013
# Max accuracy of 0.170 achieved at epoch 37
# Average accuracy 0.176 +- 0.005. Av loss 169.285

# %% [markdown]
# ## Influence of image size

# %%
total_acc, total_loss = [], []
for im_size_ in [30, 50, 70]:
    main_acc, main_loss = [], []
    for trial in range(5):
        loss, acc, test_loss, test_acc, idx_f, times, o2 = evaluating_model(im_size_, weighted=0.999)
        main_loss.append(min(test_loss))
        main_acc.append(max(test_acc))
    total_acc.append(main_acc)
    total_loss.append(main_loss)
    print('Average accuracy {:.3f} +- {:.3f}. Av loss {:.3f}'.format(np.mean(main_acc), np.std(main_acc), np.mean(main_loss)))
# Out:
# Epoch 50. Train Loss: 1.985 Accuracy: 0.511 Test Loss: 168.105 Accuracy: 0.189
# Average time per epoch 15.647s +- 1.215
# Max accuracy of 0.204 achieved at epoch 31
# Epoch 50. Train Loss: 1.941 Accuracy: 0.527 Test Loss: 168.889 Accuracy: 0.193
# Average time per epoch 15.389s +- 1.224
# Max accuracy of 0.202 achieved at epoch 24
# Epoch 16. Train Loss: 4.783 Accuracy: 0.316 Test Loss: 170.309 Accuracy: 0.189

# %%
# data parameters
tables = list(range(1,95))
random.shuffle(tables)

train_tables, test_tables, validation_tables = \
tables[:int(len(tables)*0.6)], tables[int(len(tables)*0.6):int(len(tables)*0.85)], tables[int(len(tables)*0.85):]

# model parameters
MAX_V = 30
mini_batch_size = 50
n_epochs=50

im_size = 40

lr = 0.0001
inp_size = 4 + MAX_V*6

model = ImagesP3(31, MAX_V, im_size)
optimizer = optim.Adam(model.parameters(), lr=lr)
criterion2 = nn.CrossEntropyLoss() 
criterion1 = nn.MSELoss()

# %%
loss, acc, test_loss, test_acc, idx_f, times = [], [], [], [], [], []
for epoch in range(n_epochs):
    current_time = time.time()
    train_l, accuracy, test_l, test_a, idx_failures, output = \
    epoch_train(model, train_tables, test_tables, optimizer, criterion1, criterion2, epoch, im_size=im_size, simple=True)
    times.append(time.time() - current_time)
    loss.append(train_l)
    test_loss.append(test_l)
    acc.append(accuracy)
    test_acc.append(test_a)
    idx_f.append(idx_failures)
    
print('\nAverage time per epoch {:.3f}s +- {:.3f}'.format(np.mean(times), 2*np.std(times)))

max_acc = np.max(test_acc)
iter_max = np.where(test_acc ==  max_acc)

print('Max accuracy of {:.3f} achieved at epoch {}'.format(max_acc, iter_max[0][0]))

# %%
f, ax = plt.subplots(2, 1, figsize=(20,10))
ax[0].plot(loss)
ax[0].plot(test_loss)
ax[1].plot(acc)
ax[1].plot(test_acc)
plt.show()

# %%
fig, ax = plt.subplots(1,5, figsize=(15,4))
k = 0
for i in idx_f[::-1]:
    if len(i) > 0:
        ax[k].hist(i, bins=50)
        k += 1
    if k == 5:
        plt.show()
        break

# %%
output[0].detach()
a = nn.Softmax()
_, jj = torch.max(output, dim=1)
_, j = torch.max(a(output), dim=1)

# %%
j == jj

# %%
def test_results(test_tables, model):
    test_loss = 0
    test_acc = []
    idx_failures = []

    for k,TABLE in enumerate(test_tables):
        data = np.load('./relative_data/data_vector_{}.npy'.format(TABLE), allow_pickle=True).tolist()
        data_y = np.load('./relative_data/data_vector_y_{}.npy'.format(TABLE), allow_pickle=True).tolist()

        idx = list(data.keys())
        #random.shuffle(idx)

        for b in range(0, len(idx), mini_batch_size):

            t_idx = idx[b:b+mini_batch_size]

            x = np.asarray([np.hstack(data[i]) for i in t_idx])
            y = np.hstack([data_y[i] for i in t_idx])

            test_x = torch.tensor(x).type(torch.FloatTensor)
            test_y = torch.tensor(y).type(torch.LongTensor)

            output = model(test_x)
            batch_loss = criterion(output, test_y)


            test_loss += batch_loss.item()
            _, a = torch.max(output,1)
            test_acc.append(float((test_y == a).sum())/len(test_y))

            idx_failures += [t_idx[i] for i in np.where(test_y != a)[0]]
                
    return test_loss, test_acc, idx_failures, output, test_y, test_x

# %%
mini_batch_size = 10
idx = list(range(1,len(data)))
for b in range(0, len(idx), mini_batch_size):

            t_idx = idx[b:b+mini_batch_size]
            x = np.asarray([np.hstack(data[i][0]) for i in t_idx])
            
            y = np.hstack([data_y[i] for i in t_idx])
            
            x_padded = np.zeros((len(t_idx), inp_size))
            for i in range(len(t_idx)):
                x_padded[i, :len(x[i])] = x[i]
            
            train_x = torch.tensor(x_padded).type(torch.FloatTensor)
            
            #train_y = torch.zeros(mini_batch_size, MAX_V).type(torch.LongTensor)
            #train_y[range(mini_batch_size), y] = 1

            train_y = torch.tensor(y).type(torch.LongTensor)
            
            output = model(train_x)
            
            _, a = torch.max(output,1)
            acc.append((train_y == a).sum())

# %%
data = np.load('./minmax_data/data_vector_{}.npy'.format(1), allow_pickle=True).tolist()

# %%
b = torch.ones(30).reshape(30,1).type(torch.FloatTensor)

# %%
t_idx = list(range(3,7))
x = np.asarray([np.hstack(data[i]) for i in t_idx])

# %%
c = torch.tensor(np.asarray(data[3][1:])).type(torch.FloatTensor)
d = torch.tensor(np.asarray(data[3][:1])).type(torch.FloatTensor)

# %%
d.shape

# %%
r = torch.cat([b,c], dim=1).view(1, -1)

# %%
r.view(30,-1)

# %%
rr = torch.cat([d,r], axis=1)

# %%
rr

# %%
for e,i in enumerate(train_y):
    x = train_x[e]
    inp = x[:4]
    cars = x[4:]
    c = a[e]
    if i != c:
        print('real', i)
        print(cars[i*6:i*6+6])
        print('pred', c)
        print(cars[c*6:c*6+6])
